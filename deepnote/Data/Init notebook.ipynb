# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# Collecting pandasai
#   Downloading pandasai-0.2.13-py3-none-any.whl (17 kB)
# Collecting icecream
#   Downloading icecream-2.1.3-py2.py3-none-any.whl (8.4 kB)
# Collecting matplotlib<4.0.0,>=3.7.1
#   Downloading matplotlib-3.7.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 96.1 MB/s eta 0:00:00
# Collecting pandas<3.0.0,>=2.0.1
#   Downloading pandas-2.0.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 123.2 MB/s eta 0:00:00
# Collecting ipython<9.0.0,>=8.13.1
#   Downloading ipython-8.13.2-py3-none-any.whl (797 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.7/797.7 KB 104.6 MB/s eta 0:00:00
# Collecting openai<0.28.0,>=0.27.5
#   Downloading openai-0.27.6-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 KB 17.0 MB/s eta 0:00:00
# Collecting astor<0.9.0,>=0.8.1
#   Downloading astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Collecting python-dotenv<2.0.0,>=1.0.0
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: pygments>=2.2.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from icecream->-r ./requirements.txt (line 2)) (2.13.0)
# Requirement already satisfied: executing>=0.3.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from icecream->-r ./requirements.txt (line 2)) (1.1.1)
# Collecting colorama>=0.3.9
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: asttokens>=2.0.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from icecream->-r ./requirements.txt (line 2)) (2.0.8)
# Requirement already satisfied: six in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from asttokens>=2.0.1->icecream->-r ./requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython<9.0.0,>=8.13.1->pandasai->-r ./requirements.txt (line 1)) (3.0.31)
# Requirement already satisfied: jedi>=0.16 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython<9.0.0,>=8.13.1->pandasai->-r ./requirements.txt (line 1)) (0.17.2)
# Requirement already satisfied: matplotlib-inline in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython<9.0.0,>=8.13.1->pandasai->-r ./requirements.txt (line 1)) (0.1.6)
# Requirement already satisfied: pickleshare in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython<9.0.0,>=8.13.1->pandasai->-r ./requirements.txt (line 1)) (0.7.5)
# Requirement already satisfied: pexpect>4.3 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython<9.0.0,>=8.13.1->pandasai->-r ./requirements.txt (line 1)) (4.8.0)
# Requirement already satisfied: traitlets>=5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython<9.0.0,>=8.13.1->pandasai->-r ./requirements.txt (line 1)) (5.5.0)
# Requirement already satisfied: stack-data in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython<9.0.0,>=8.13.1->pandasai->-r ./requirements.txt (line 1)) (0.5.1)
# Requirement already satisfied: decorator in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython<9.0.0,>=8.13.1->pandasai->-r ./requirements.txt (line 1)) (5.1.1)
# Requirement already satisfied: typing-extensions in /shared-libs/python3.9/py/lib/python3.9/site-packages (from ipython<9.0.0,>=8.13.1->pandasai->-r ./requirements.txt (line 1)) (4.4.0)
# Requirement already satisfied: backcall in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython<9.0.0,>=8.13.1->pandasai->-r ./requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib<4.0.0,>=3.7.1->pandasai->-r ./requirements.txt (line 1)) (1.0.5)
# Requirement already satisfied: packaging>=20.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from matplotlib<4.0.0,>=3.7.1->pandasai->-r ./requirements.txt (line 1)) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib<4.0.0,>=3.7.1->pandasai->-r ./requirements.txt (line 1)) (9.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from matplotlib<4.0.0,>=3.7.1->pandasai->-r ./requirements.txt (line 1)) (3.0.9)
# Collecting importlib-resources>=3.2.0
#   Downloading importlib_resources-5.12.0-py3-none-any.whl (36 kB)
# Requirement already satisfied: cycler>=0.10 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib<4.0.0,>=3.7.1->pandasai->-r ./requirements.txt (line 1)) (0.11.0)
# Requirement already satisfied: numpy>=1.20 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib<4.0.0,>=3.7.1->pandasai->-r ./requirements.txt (line 1)) (1.23.4)
# Requirement already satisfied: fonttools>=4.22.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib<4.0.0,>=3.7.1->pandasai->-r ./requirements.txt (line 1)) (4.37.4)
# Requirement already satisfied: python-dateutil>=2.7 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from matplotlib<4.0.0,>=3.7.1->pandasai->-r ./requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from matplotlib<4.0.0,>=3.7.1->pandasai->-r ./requirements.txt (line 1)) (1.4.4)
# Requirement already satisfied: requests>=2.20 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from openai<0.28.0,>=0.27.5->pandasai->-r ./requirements.txt (line 1)) (2.28.1)
# Requirement already satisfied: tqdm in /shared-libs/python3.9/py/lib/python3.9/site-packages (from openai<0.28.0,>=0.27.5->pandasai->-r ./requirements.txt (line 1)) (4.64.1)
# Requirement already satisfied: aiohttp in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from openai<0.28.0,>=0.27.5->pandasai->-r ./requirements.txt (line 1)) (3.8.3)
# Requirement already satisfied: pytz>=2020.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pandas<3.0.0,>=2.0.1->pandasai->-r ./requirements.txt (line 1)) (2022.5)
# Requirement already satisfied: tzdata>=2022.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pandas<3.0.0,>=2.0.1->pandasai->-r ./requirements.txt (line 1)) (2022.5)
# Requirement already satisfied: zipp>=3.1.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib<4.0.0,>=3.7.1->pandasai->-r ./requirements.txt (line 1)) (3.9.0)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jedi>=0.16->ipython<9.0.0,>=8.13.1->pandasai->-r ./requirements.txt (line 1)) (0.7.1)
# Requirement already satisfied: ptyprocess>=0.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from pexpect>4.3->ipython<9.0.0,>=8.13.1->pandasai->-r ./requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: wcwidth in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython<9.0.0,>=8.13.1->pandasai->-r ./requirements.txt (line 1)) (0.2.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests>=2.20->openai<0.28.0,>=0.27.5->pandasai->-r ./requirements.txt (line 1)) (1.26.12)
# Requirement already satisfied: idna<4,>=2.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests>=2.20->openai<0.28.0,>=0.27.5->pandasai->-r ./requirements.txt (line 1)) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests>=2.20->openai<0.28.0,>=0.27.5->pandasai->-r ./requirements.txt (line 1)) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests>=2.20->openai<0.28.0,>=0.27.5->pandasai->-r ./requirements.txt (line 1)) (2022.9.24)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from aiohttp->openai<0.28.0,>=0.27.5->pandasai->-r ./requirements.txt (line 1)) (4.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from aiohttp->openai<0.28.0,>=0.27.5->pandasai->-r ./requirements.txt (line 1)) (1.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from aiohttp->openai<0.28.0,>=0.27.5->pandasai->-r ./requirements.txt (line 1)) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from aiohttp->openai<0.28.0,>=0.27.5->pandasai->-r ./requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from aiohttp->openai<0.28.0,>=0.27.5->pandasai->-r ./requirements.txt (line 1)) (22.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from aiohttp->openai<0.28.0,>=0.27.5->pandasai->-r ./requirements.txt (line 1)) (6.0.2)
# Requirement already satisfied: pure-eval in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from stack-data->ipython<9.0.0,>=8.13.1->pandasai->-r ./requirements.txt (line 1)) (0.2.2)
# Installing collected packages: python-dotenv, importlib-resources, colorama, astor, pandas, matplotlib, icecream, openai, ipython, pandasai
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.2.5
#     Not uninstalling pandas at /shared-libs/python3.9/py/lib/python3.9/site-packages, outside environment /root/venv
#     Can't uninstall 'pandas'. No files were found to uninstall.
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.6.0
#     Not uninstalling matplotlib at /shared-libs/python3.9/py/lib/python3.9/site-packages, outside environment /root/venv
#     Can't uninstall 'matplotlib'. No files were found to uninstall.
#   Attempting uninstall: ipython
#     Found existing installation: ipython 8.5.0
#     Not uninstalling ipython at /shared-libs/python3.9/py-core/lib/python3.9/site-packages, outside environment /root/venv
#     Can't uninstall 'ipython'. No files were found to uninstall.
# Successfully installed astor-0.8.1 colorama-0.4.6 icecream-2.1.3 importlib-resources-5.12.0 ipython-8.13.2 matplotlib-3.7.1 openai-0.27.6 pandas-2.0.1 pandasai-0.2.13 python-dotenv-1.0.0
# WARNING: You are using pip version 22.0.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=fa0ff5c2-b244-406d-b1f4-a2f4cd653e27' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
